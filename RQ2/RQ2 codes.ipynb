# %% [markdown]
# # ICMP FLOOD DOS with different configuration runs

# %%
import matplotlib.pyplot as plt


    
durations = {
"30134":"329.83446",
"719":"331.74655",
"3811":"331.89082"
}

ICMP_NAMES = {
"30134":"ICMP FLOOD with regular conf",
"719":"ICMP FLOOD with modified conf",
"3811":"ICMP FLOOD with modified conf and nice -20"
}



data = []
with open('ICMP_TOP_USAGES.txt', 'r') as file:
    for line in file:
        if 'root' in line:
            fields = line.split()
            data.append(fields)


# Separate the data for each root process
root_processes = {}
for entry in data:
    pid = entry[0]
    if pid not in root_processes:
        root_processes[pid] = {'cpu': [], 'mem': []}
    root_processes[pid]['cpu'].append(float(entry[8]))
    root_processes[pid]['mem'].append(float(entry[9]))

# Plotting CPU usage
plt.rcParams.update({'font.size': 18})
# plt.figure(figsize=(10, 5))
plt.figure(figsize=(12, 6))
plt.title('CPU Usage', fontsize=28)
plt.xlabel('Duration (s)', fontsize=24)
plt.ylabel('CPU (%)', fontsize=24)

plt.xticks(fontsize=24)
plt.yticks(fontsize=24)

for pid, process_data in root_processes.items():
    # Get the duration for the process
    duration = float(durations.get(pid, 0))
    # Create the x-axis values representing the duration
    time_values = [duration * (i / (len(process_data['cpu']) - 1)) for i in range(len(process_data['cpu']))]
    #plt.plot(time_values, process_data['cpu'], label='Process ' + pid)
    plt.plot(time_values, process_data['cpu'], label=ICMP_NAMES[pid])

plt.legend()
plt.savefig('ICMPs_CPU_RQ2.pdf')
plt.show()

# Plotting memory usage
# plt.figure(figsize=(10, 5))
plt.figure(figsize=(12, 6))
plt.title('Memory Usage', fontsize=28)
plt.xlabel('Duration (s)', fontsize=24)
plt.ylabel('Memory (%)', fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)

for pid, process_data in root_processes.items():
    # Get the duration for the process
    duration = float(durations.get(pid, 0))
    # Create the x-axis values representing the duration
    time_values = [duration * (i / (len(process_data['mem']) - 1)) for i in range(len(process_data['mem']))]
    #plt.plot(time_values, process_data['mem'], label='Process ' + pid)
    plt.plot(time_values, process_data['mem'], label=ICMP_NAMES[pid])

plt.legend()
plt.savefig('ICMPs_MEM_RQ2.pdf')
plt.show()

# %% [markdown]
# # TCP SYN FLOOD DOS with different configuration runs

# %%
import matplotlib.pyplot as plt


    
durations = {
"7648":"327.151377",
"10705":"330.84546",
"13629":"328.98263"
}

    
SYN_NAMES = {
"7648":"SYN FLOOD with regular conf",
"10705":"SYN FLOOD with modified conf",
"13629":"SYN FLOOD with modified conf and nice -20"
}


data = []
with open('TCP_TOP_USAGES.txt', 'r') as file:
    for line in file:
        if 'root' in line:
            fields = line.split()
            data.append(fields)


# Separate the data for each root process
root_processes = {}
for entry in data:
    pid = entry[0]
    if pid not in root_processes:
        root_processes[pid] = {'cpu': [], 'mem': []}
    root_processes[pid]['cpu'].append(float(entry[8]))
    root_processes[pid]['mem'].append(float(entry[9]))

# Plotting CPU usage
plt.rcParams.update({'font.size': 18})
# plt.figure(figsize=(10, 5))
plt.figure(figsize=(12, 6))
plt.title('CPU Usage', fontsize=28)
plt.xlabel('Duration (s)', fontsize=24)
plt.ylabel('CPU (%)', fontsize=24)

plt.xticks(fontsize=24)
plt.yticks(fontsize=24)

for pid, process_data in root_processes.items():
    # Get the duration for the process
    duration = float(durations.get(pid, 0))
    # Create the x-axis values representing the duration
    time_values = [duration * (i / (len(process_data['cpu']) - 1)) for i in range(len(process_data['cpu']))]
    #plt.plot(time_values, process_data['cpu'], label='Process ' + pid)
    plt.plot(time_values, process_data['cpu'], label=SYN_NAMES[pid])

plt.legend()
plt.savefig('SYNs_CPU_RQ2.pdf')
plt.show()

# Plotting memory usage
# plt.figure(figsize=(10, 5))
plt.figure(figsize=(12, 6))
plt.title('Memory Usage', fontsize=28)
plt.xlabel('Duration (s)', fontsize=24)
plt.ylabel('Memory (%)', fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)

for pid, process_data in root_processes.items():
    # Get the duration for the process
    duration = float(durations.get(pid, 0))
    # Create the x-axis values representing the duration
    time_values = [duration * (i / (len(process_data['mem']) - 1)) for i in range(len(process_data['mem']))]
    #plt.plot(time_values, process_data['mem'], label='Process ' + pid)
    plt.plot(time_values, process_data['mem'], label=SYN_NAMES[pid])

plt.legend()
plt.savefig('SYNs_MEM_RQ2.pdf')
plt.show()

# %% [markdown]
# # HTTP FLOOD DOS with different configuration runs

# %%
import matplotlib.pyplot as plt


    
durations = {
"18416":"280.32507",
"21482":"273.36599",
"26653":"276.32129"
}

HTTP_NAMES = {
"18416":"HTTP FLOOD with regular conf",
"21482":"HTTP FLOOD with modified conf",
"26653":"HTTP FLOOD with modified conf with nice -20"
}


data = []
with open('HTTP_TOP_USAGES.txt', 'r') as file:
    for line in file:
        if 'root' in line:
            fields = line.split()
            data.append(fields)


# Separate the data for each root process
root_processes = {}
for entry in data:
    pid = entry[0]
    if pid not in root_processes:
        root_processes[pid] = {'cpu': [], 'mem': []}
    root_processes[pid]['cpu'].append(float(entry[8]))
    root_processes[pid]['mem'].append(float(entry[9]))

# Plotting CPU usage
plt.rcParams.update({'font.size': 18})
# plt.figure(figsize=(10, 5))
plt.figure(figsize=(12, 6))
plt.title('CPU Usage', fontsize=28)
plt.xlabel('Duration (s)', fontsize=24)
plt.ylabel('CPU (%)', fontsize=24)

plt.xticks(fontsize=24)
plt.yticks(fontsize=24)

for pid, process_data in root_processes.items():
    # Get the duration for the process
    duration = float(durations.get(pid, 0))
    # Create the x-axis values representing the duration
    time_values = [duration * (i / (len(process_data['cpu']) - 1)) for i in range(len(process_data['cpu']))]
    #plt.plot(time_values, process_data['cpu'], label='Process ' + pid)
    plt.plot(time_values, process_data['cpu'], label=HTTP_NAMES[pid])

plt.legend()
plt.savefig('HTTPs_CPU_RQ2.pdf')
plt.show()

# Plotting memory usage
# plt.figure(figsize=(10, 5))
plt.figure(figsize=(12, 6))
plt.title('Memory Usage', fontsize=28)
plt.xlabel('Duration (s)', fontsize=24)
plt.ylabel('Memory (%)', fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)

for pid, process_data in root_processes.items():
    # Get the duration for the process
    duration = float(durations.get(pid, 0))
    # Create the x-axis values representing the duration
    time_values = [duration * (i / (len(process_data['mem']) - 1)) for i in range(len(process_data['mem']))]
    #plt.plot(time_values, process_data['mem'], label='Process ' + pid)
    plt.plot(time_values, process_data['mem'], label=HTTP_NAMES[pid])

plt.legend()
plt.savefig('HTTPs_MEM_RQ2.pdf')
plt.show()
